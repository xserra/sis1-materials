# %%
# !git clone https://github.com/pzinemanas/sis1lab.git

import numpy as np
import matplotlib.pyplot as plt
from scipy import signal
from sis1lab.util import load_audio, plot_complex, plot_zeros_poles
# Out:
# Cloning into 'sis1lab'...
# remote: Enumerating objects: 59, done.
# remote: Counting objects: 100% (59/59), done.
# remote: Compressing objects: 100% (43/43), done.
# remote: Total 59 (delta 16), reused 28 (delta 6), pack-reused 0
# Unpacking objects: 100% (59/59), done.

# %%
#exercise 6
z=[-1/8]
p=[-0.8] 
plot_zeros_poles(z,p)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
#exercise 7
n=np.arange(11)
y=np.power(0.9, n)*np.cos(np.pi*2*0.2*n)
plt.figure(1, figsize=(9.5, 3.5))
plt.plot(n,y,'x', linewidth=0)
plt.axis([0,10,-1,1])
plt.xlabel('time (n)')
plt.grid()
plt.ylabel('amplitude')
# Out:
# Text(0, 0.5, 'amplitude')

# %%
import IPython.display as ipd
from sis1lab.util import plot_signals
fs=1
N=11
x=np.zeros(N)
x[0]=1
fn=2*np.pi*200
r=0.9
b = [1]
a = [1, -2*r*np.cos(2*np.pi*(0.2)), r**2]
y = signal.lfilter(b, a, x)
plt.figure(1, figsize=(9.5, 3.5))
plt.plot(y,'x', linewidth=0)
plt.axis([0,10,-1,1])
plt.xlabel('time (n)')
plt.grid()
plt.ylabel('amplitude')
# Out:
# Text(0, 0.5, 'amplitude')
