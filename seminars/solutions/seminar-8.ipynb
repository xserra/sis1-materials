# %%
# !git clone https://github.com/pzinemanas/sis1lab.git

import numpy as np
import matplotlib.pyplot as plt
from scipy import signal
from sis1lab.util import load_audio, plot_complex, plot_zeros_poles
# Out:
# Cloning into 'sis1lab'...
# remote: Enumerating objects: 59, done.
# remote: Counting objects: 100% (59/59), done.
# remote: Compressing objects: 100% (43/43), done.
# remote: Total 59 (delta 16), reused 28 (delta 6), pack-reused 0
# Unpacking objects: 100% (59/59), done.

# %%
from sis1lab.util import plot_complex, plot_zeros_poles
z=np.roots([1,1,1])
p=np.roots([0,0])
print(z)
print(p)
# Out:
# [-0.5+0.8660254j -0.5-0.8660254j]
# []

# %%
plot_complex([-0.5+0.8660254j, -0.5-0.8660254j])

# %%
plot_zeros_poles(z,p)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
z=[1, np.exp(1j*np.pi/2),np.exp(1j*-np.pi/2),0.9*np.exp(1j*np.pi/3),0.9*np.exp(1j*-np.pi/3)]
p=[0,0,0,0,0] 
plot_zeros_poles(z,p)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
z=[+1j, -1j,2,-2]
p=[0,0,0,0] 
plot_zeros_poles(z,p)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# exercise 5
z=[1, -1,0.8*np.exp(1j*np.pi/4),0.8*np.exp(-1j*np.pi/4),1j,-1j]
p=[0,0,0,0,0,0] 
plot_zeros_poles(z,p)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# exercise 7
z=[1, -1,1j, -1j]
p=[0,0,0,0] 
plot_zeros_poles(z,p)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
#exercise 7
from sis1lab.util import plot_frequency_response

ww = np.arange(-np.pi, np.pi, np.pi/500)
w, HH = signal.freqz([1, 0, 0, 0,-1],1,ww)

plot_frequency_response(ww, HH)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
#exercise 6
from sis1lab.util import plot_frequency_response

ww = np.arange(-np.pi, np.pi, np.pi/500)
w, HH = signal.freqz([1,-1],1,ww)

plot_frequency_response(ww, HH)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
#exercise 6
from sis1lab.util import plot_frequency_response

ww = np.arange(-np.pi, np.pi, np.pi/500)
w, HH = signal.freqz([1,-1],1,ww)

plt.plot(ww,np.abs(2*np.sin(ww/2)))

# %%
np.abs(np.roots([1,0,0,0,0,.9]))
# Out:
# array([0.97914836, 0.97914836, 0.97914836, 0.97914836, 0.97914836])
